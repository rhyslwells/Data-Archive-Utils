# %%
import os
import re
import yaml

FRONTMATTER_RE = re.compile(r'(?s)^---\s*\n(.*?)\n---\s*(.*)$')

# %%
def assign_category_from_folder(base_folder, category_folder_map, force=False):
    """
    Assign a category to all notes in a folder based on the folder name.

    Parameters:
    - base_folder: str, path containing subfolders with notes
    - category_folder_map: dict, category -> folder name
      e.g. {"DS": "data-science", "ML": "machine-learning"}
    - force: bool, overwrite existing category if True
    """
    # Reverse mapping: folder -> category
    folder_to_category = {v.lower(): k for k, v in category_folder_map.items()}

    for category, folder_name in category_folder_map.items():
        folder_path = os.path.join(base_folder, folder_name)
        if not os.path.exists(folder_path):
            print(f"Folder {folder_path} does not exist, skipping.")
            continue

        for root, _, files in os.walk(folder_path):
            for file in files:
                if not file.endswith(".md"):
                    continue
                filepath = os.path.join(root, file)
                with open(filepath, "r", encoding="utf-8") as f:
                    content = f.read()

                m = FRONTMATTER_RE.match(content)
                if not m:
                    continue
                yaml_text, body = m.groups()
                yaml_block = yaml.safe_load(yaml_text) or {}

                if force or "category" not in yaml_block or not yaml_block["category"]:
                    yaml_block["category"] = category
                    new_yaml = yaml.dump(yaml_block, sort_keys=False).strip()
                    new_content = f"---\n{new_yaml}\n---\n{body}"
                    with open(filepath, "w", encoding="utf-8") as f:
                        f.write(new_content)
                    print(f"Updated {filepath} -> {category}")
                else:
                    print(f"Skipped {filepath}, already has category {yaml_block['category']}")

# %%
CATEGORY_TO_FOLDER = {
    "DS": "data-science",
    "ML": "machine-learning",
    "DE": "data-engineering",
    "STATISTICS": "statistics",
    "CS": "computer-science",
    "LANG": "natural-language",
    "DEVOPS": "devops",
    "PM": "project-management",
    "INDUSTRY": "industry",
    "DATA_ANALYSIS": "data-analysis",
    "NONE": "uncategorised",
    "DL": "deep-learning",
    "OTHER": "OTHER",
    "PAPER": "PAPER"
}

# %%
assign_category_from_folder(r"categories", CATEGORY_TO_FOLDER, force=True)
# Out:
# Updated categories\data-science\ACF Plots.md -> DS
# Updated categories\data-science\Additive vs Multiplicative Models Time Series.md -> DS
# Updated categories\data-science\ADF Test.md -> DS
# Updated categories\data-science\Agent Exploration.md -> DS
# Updated categories\data-science\Agentic Solutions.md -> DS
# Updated categories\data-science\AI.md -> DS
# Updated categories\data-science\ARIMA vs Random Forest in Time Series.md -> DS
# Updated categories\data-science\ARIMA.md -> DS
# Updated categories\data-science\Autocorrelation vs Autoregression.md -> DS
# Updated categories\data-science\Autocorrelation.md -> DS
# Updated categories\data-science\Autoregression.md -> DS
# Updated categories\data-science\Baseline Forecast.md -> DS
# Updated categories\data-science\Basics of Time Series.md -> DS
# Updated categories\data-science\Batch gradient descent.md -> DS
# Updated categories\data-science\Bellman Equations.md -> DS
# Updated categories\data-science\Bias-Variance Trade Off.md -> DS
# Updated categories\data-science\Capability.md -> DS
# Updated categories\data-science\Choosing a Threshold.md -> DS
# Updated categories\data-science\Choosing the Number of Clusters.md -> DS
# Updated categories\data-science\Clustermap.md -> DS
# Updated categories\data-science\Covariance Structures.md -> DS
# Updated categories\data-science\Cross Validation.md -> DS
# Updated categories\data-science\Data Assessment.md -> DS
# Updated categories\data-science\Data Collection.md -> DS
# Updated categories\data-science\Data Mining - CRISP.md -> DS
# Updated categories\data-science\Data Preparation.md -> DS
# Updated categories\data-science\Data Science.md -> DS
# Updated categories\data-science\Data Scientist.md -> DS
# Updated categories\data-science\Data Understanding.md -> DS
# Updated categories\data-science\Datasets.md -> DS
# Updated categories\data-science\Decomposition in Time Series.md -> DS
# Updated categories\data-science\Differencing in Time Series.md -> DS
# Updated categories\data-science\DS & ML Portal.md -> DS
# Updated categories\data-science\Evaluating Time Series Forecasts.md -> DS
# Updated categories\data-science\Evolving Seasonality.md -> DS
# Updated categories\data-science\F-statistic.md -> DS
# Updated categories\data-science\Feature Engineering.md -> DS
# Updated categories\data-science\Feature Scaling.md -> DS
# Updated categories\data-science\Feature Selection vs Feature Importance.md -> DS
# Updated categories\data-science\Forecasting using Lags.md -> DS
# Updated categories\data-science\Forward Propagation.md -> DS
# Updated categories\data-science\Gaussian Mixture Models.md -> DS
# Updated categories\data-science\Gitlab.md -> DS
# Updated categories\data-science\Gompertz Model.md -> DS
# Updated categories\data-science\Good Enough Principle in Data Projects.md -> DS
# Updated categories\data-science\GraphRAG.md -> DS
# Updated categories\data-science\Handling Missing Data.md -> DS
# Updated categories\data-science\Holt-Winters (Exponential Smoothing).md -> DS
# Updated categories\data-science\Holt-Winters vs ARIMA.md -> DS
# Updated categories\data-science\Holt’s Linear Trend Model (Double Exponential Smoothing).md -> DS
# Updated categories\data-science\how do you do the data selection.md -> DS
# Updated categories\data-science\Imbalanced Datasets.md -> DS
# Updated categories\data-science\Interpolation.md -> DS
# Updated categories\data-science\Intervention Analysis.md -> DS
# Updated categories\data-science\Joining Time Series.md -> DS
# Updated categories\data-science\Kernel Machines.md -> DS
# Updated categories\data-science\KPSS Test.md -> DS
# Updated categories\data-science\Latency.md -> DS
# Updated categories\data-science\Logistic Model Curve.md -> DS
# Updated categories\data-science\LSTM in Time Series.md -> DS
# Updated categories\data-science\Mean Absolute Percentage Error.md -> DS
# Updated categories\data-science\MNIST.md -> DS
# Updated categories\data-science\Normalisation.md -> DS
# Updated categories\data-science\Out-of-sample rolling forecast evaluation.md -> DS
# Updated categories\data-science\PACF Plots.md -> DS
# Updated categories\data-science\Performance Dimensions.md -> DS
# Updated categories\data-science\pmdarima.md -> DS
# Updated categories\data-science\Properties of Time Series Models.md -> DS
# Updated categories\data-science\Random Forest Regression.md -> DS
# Updated categories\data-science\Residuals in Time Series.md -> DS
# Updated categories\data-science\Scatter Plots.md -> DS
# Updated categories\data-science\Scientific Method.md -> DS
# Updated categories\data-science\Scipy.md -> DS
# Updated categories\data-science\Seasonal Naive Forecast.md -> DS
# Updated categories\data-science\Seasonality in Time Series.md -> DS
# Updated categories\data-science\SHapley Additive exPlanations.md -> DS
# Updated categories\data-science\Shot Learning.md -> DS
# Updated categories\data-science\Silhouette Analysis.md -> DS
# Updated categories\data-science\Simple Exponential Smoothing (SES).md -> DS
# Updated categories\data-science\sklearn datasets.md -> DS
# Updated categories\data-science\SMOTE (Synthetic Minority Over-sampling Technique).md -> DS
# Updated categories\data-science\SparseCategorialCrossentropy or CategoricalCrossEntropy.md -> DS
# Updated categories\data-science\stack memory.md -> DS
# Updated categories\data-science\Stacking.md -> DS
# Updated categories\data-science\Stationary Time Series.md -> DS
# Updated categories\data-science\STL Decomposition.md -> DS
# Updated categories\data-science\Time Series Forecasting.md -> DS
# Updated categories\data-science\Time Series Forecasts in Business.md -> DS
# Updated categories\data-science\Time Series Learning Resources.md -> DS
# Updated categories\data-science\Time Series Shocks.md -> DS
# Updated categories\data-science\Time Series.md -> DS
# Updated categories\data-science\Trends in Time Series.md -> DS
# Updated categories\machine-learning\Accuracy.md -> ML
# Updated categories\machine-learning\Activation atlases.md -> ML
# Updated categories\machine-learning\Activation Function.md -> ML
# Updated categories\machine-learning\Active Learning.md -> ML
# Updated categories\machine-learning\Adam Optimizer.md -> ML
# Updated categories\machine-learning\Adaptive Learning Rates.md -> ML
# Updated categories\machine-learning\Adjusted R squared.md -> ML
# Updated categories\machine-learning\Agent-Based Modelling.md -> ML
# Updated categories\machine-learning\AIC in Model Evaluation.md -> ML
# Updated categories\machine-learning\Anomaly Detection in Time Series.md -> ML
# Updated categories\machine-learning\Anomaly Detection with Clustering.md -> ML
# Updated categories\machine-learning\Anomaly Detection with Statistical Methods.md -> ML
# Updated categories\machine-learning\Anomaly Detection.md -> ML
# Updated categories\machine-learning\Assessing Gen AI generated content.md -> ML
# Updated categories\machine-learning\AUC.md -> ML
# Updated categories\machine-learning\Automated Feature Creation.md -> ML
# Updated categories\machine-learning\AutoML.md -> ML
# Updated categories\machine-learning\Backpropagation.md -> ML
# Updated categories\machine-learning\Batch Normalisation.md -> ML
# Updated categories\machine-learning\Bias in ML.md -> ML
# Updated categories\machine-learning\Binary Classification.md -> ML
# Updated categories\machine-learning\Boosting.md -> ML
# Updated categories\machine-learning\Business value of anomaly detection.md -> ML
# Updated categories\machine-learning\CART.md -> ML
# Updated categories\machine-learning\CatBoost.md -> ML
# Updated categories\machine-learning\Challenges to Model Deployment.md -> ML
# Updated categories\machine-learning\Class Separability.md -> ML
# Updated categories\machine-learning\Classification Report.md -> ML
# Updated categories\machine-learning\Classification.md -> ML
# Updated categories\machine-learning\Cluster Density.md -> ML
# Updated categories\machine-learning\Cluster Seperation.md -> ML
# Updated categories\machine-learning\Clustering.md -> ML
# Updated categories\machine-learning\Collaborative Filtering.md -> ML
# Updated categories\machine-learning\conceptual data model.md -> ML
# Updated categories\machine-learning\Confusion Matrix.md -> ML
# Updated categories\machine-learning\Cost Function.md -> ML
# Updated categories\machine-learning\Cost-Sensitive Analysis.md -> ML
# Updated categories\machine-learning\Cross Entropy.md -> ML
# Updated categories\machine-learning\Customer Growth Modeling.md -> ML
# Updated categories\machine-learning\Data Selection in ML.md -> ML
# Updated categories\machine-learning\Data Transformation in Machine Learning.md -> ML
# Updated categories\machine-learning\Database Schema.md -> ML
# Updated categories\machine-learning\DBSCAN.md -> ML
# Updated categories\machine-learning\Decision Theory.md -> ML
# Updated categories\machine-learning\Decision Tree.md -> ML
# Updated categories\machine-learning\Decision Trees are Fragile.md -> ML
# Updated categories\machine-learning\Deep Learning Frameworks.md -> ML
# Updated categories\machine-learning\Deep Q-Learning.md -> ML
# Updated categories\machine-learning\Dendrograms.md -> ML
# Updated categories\machine-learning\Determining Threshold Values.md -> ML
# Updated categories\machine-learning\Dimension Table.md -> ML
# Updated categories\machine-learning\Dimensional Modelling.md -> ML
# Updated categories\machine-learning\Dimensionality Reduction.md -> ML
# Updated categories\machine-learning\Dimensions.md -> ML
# Updated categories\machine-learning\Distributions in Decision Tree Leaves.md -> ML
# Updated categories\machine-learning\Dropout.md -> ML
# Updated categories\machine-learning\Dummy variable trap.md -> ML
# Updated categories\machine-learning\Edge ML.md -> ML
# Updated categories\machine-learning\emergent behavior.md -> ML
# Updated categories\machine-learning\Encoding Categorical Variables.md -> ML
# Updated categories\machine-learning\Epoch.md -> ML
# Updated categories\machine-learning\Evaluating Language Models.md -> ML
# Updated categories\machine-learning\Evaluating Logistic Regression.md -> ML
# Updated categories\machine-learning\Evaluating the effectiveness of prompts.md -> ML
# Updated categories\machine-learning\Evaluation Metrics.md -> ML
# Updated categories\machine-learning\Exploration vs Exploitation.md -> ML
# Updated categories\machine-learning\Exponential Smoothing.md -> ML
# Updated categories\machine-learning\f-regression.md -> ML
# Updated categories\machine-learning\F1 Score.md -> ML
# Updated categories\machine-learning\Fact Table.md -> ML
# Updated categories\machine-learning\FAISS.md -> ML
# Updated categories\machine-learning\Feature Engineering for Time Series.md -> ML
# Updated categories\machine-learning\Feature Evaluation.md -> ML
# Updated categories\machine-learning\Feature Extraction.md -> ML
# Updated categories\machine-learning\Feature Importance.md -> ML
# Updated categories\machine-learning\Feature Selection.md -> ML
# Updated categories\machine-learning\Feature Transformations.md -> ML
# Updated categories\machine-learning\Feed Forward Neural Network.md -> ML
# Updated categories\machine-learning\Filter Methods.md -> ML
# Updated categories\machine-learning\Fitting weights and biases of a neural network.md -> ML
# Updated categories\machine-learning\Framework for models.md -> ML
# Updated categories\machine-learning\Gaussian Model.md -> ML
# Updated categories\machine-learning\General Linear Regression.md -> ML
# Updated categories\machine-learning\Generalisation.md -> ML
# Updated categories\machine-learning\Generative Adversarial Networks.md -> ML
# Updated categories\machine-learning\Gini Impurity vs Cross Entropy.md -> ML
# Updated categories\machine-learning\Gini Impurity.md -> ML
# Updated categories\machine-learning\Gradient Boosted Trees.md -> ML
# Updated categories\machine-learning\Gradient Boosting Regressor.md -> ML
# Updated categories\machine-learning\Gradient Boosting.md -> ML
# Updated categories\machine-learning\Gradient descent in linear regression.md -> ML
# Updated categories\machine-learning\Gradient Descent.md -> ML
# Updated categories\machine-learning\granularity.md -> ML
# Updated categories\machine-learning\Graph Neural Network.md -> ML
# Updated categories\machine-learning\Graph Theory Community.md -> ML
# Updated categories\machine-learning\GridSeachCv.md -> ML
# Updated categories\machine-learning\Growth Models in Time Series.md -> ML
# Updated categories\machine-learning\GRU.md -> ML
# Updated categories\machine-learning\Hierarchical Clustering.md -> ML
# Updated categories\machine-learning\High cross validation accuracy is not directly proportional to performance on unseen test data.md -> ML
# Updated categories\machine-learning\Histogram.md -> ML
# Updated categories\machine-learning\How do we evaluate of LLM Outputs.md -> ML
# Updated categories\machine-learning\How to use Sklearn Pipeline.md -> ML
# Updated categories\machine-learning\Hyperparameter Tuning.md -> ML
# Updated categories\machine-learning\Hyperparameter.md -> ML
# Updated categories\machine-learning\Impact of multicollinearity on model parameters.md -> ML
# Updated categories\machine-learning\Inertia K Means Cost Function.md -> ML
# Updated categories\machine-learning\inference versus prediction.md -> ML
# Updated categories\machine-learning\inference.md -> ML
# Updated categories\machine-learning\initialization methods.md -> ML
# Updated categories\machine-learning\Interoperability.md -> ML
# Updated categories\machine-learning\interoperable.md -> ML
# Updated categories\machine-learning\Interpretability.md -> ML
# Updated categories\machine-learning\Interpreting logistic regression model parameters.md -> ML
# Updated categories\machine-learning\Isolated Forest.md -> ML
# Updated categories\machine-learning\Jaccard Coefficient.md -> ML
# Updated categories\machine-learning\K-means.md -> ML
# Updated categories\machine-learning\K-nearest neighbours.md -> ML
# Updated categories\machine-learning\Keras.md -> ML
# Updated categories\machine-learning\Kernel Density Estimation.md -> ML
# Updated categories\machine-learning\Kernelling.md -> ML
# Updated categories\machine-learning\Kmeans vs GMM.md -> ML
# Updated categories\machine-learning\L1 Regularisation.md -> ML
# Updated categories\machine-learning\Label encoding vs One-hot encoding.md -> ML
# Updated categories\machine-learning\Labelling data.md -> ML
# Updated categories\machine-learning\Lagrange multipliers in optimisation.md -> ML
# Updated categories\machine-learning\lambda architecture.md -> ML
# Updated categories\machine-learning\Latent Dirichlet Allocation.md -> ML
# Updated categories\machine-learning\Latent Semantic Indexing.md -> ML
# Updated categories\machine-learning\LBFGS.md -> ML
# Updated categories\machine-learning\Learning Curve.md -> ML
# Updated categories\machine-learning\Learning Rate.md -> ML
# Updated categories\machine-learning\Learning Styles.md -> ML
# Updated categories\machine-learning\LightGBM vs XGBoost vs CatBoost.md -> ML
# Updated categories\machine-learning\LightGBM.md -> ML
# Updated categories\machine-learning\Linear Regression.md -> ML
# Updated categories\machine-learning\LLM Evaluation Metrics.md -> ML
# Updated categories\machine-learning\Local Interpretable Model-agnostic Explainations.md -> ML
# Updated categories\machine-learning\Local Outlier Factor (LOF).md -> ML
# Updated categories\machine-learning\Logistic Regression does not predict probabilities.md -> ML
# Updated categories\machine-learning\Logistic regression in sklearn & Gradient Descent.md -> ML
# Updated categories\machine-learning\Logistic Regression Statsmodel Summary table.md -> ML
# Updated categories\machine-learning\Logistic Regression.md -> ML
# Updated categories\machine-learning\Loss function.md -> ML
# Updated categories\machine-learning\Loss versus Cost function.md -> ML
# Updated categories\machine-learning\Machine Learning Operations.md -> ML
# Updated categories\machine-learning\Machine Learning.md -> ML
# Updated categories\machine-learning\Manifold Learning.md -> ML
# Updated categories\machine-learning\Markov Decision Processes.md -> ML
# Updated categories\machine-learning\Maximum Likelihood Estimation.md -> ML
# Updated categories\machine-learning\Median Absolute Error.md -> ML
# Updated categories\machine-learning\Mermaid.md -> ML
# Updated categories\machine-learning\Metadata Handling.md -> ML
# Updated categories\machine-learning\Methods for Handling Outliers.md -> ML
# Updated categories\machine-learning\Metric.md -> ML
# Updated categories\machine-learning\Mini-batch gradient descent.md -> ML
# Updated categories\machine-learning\MLOPS for Time Series.md -> ML
# Updated categories\machine-learning\Model Building.md -> ML
# Updated categories\machine-learning\Model Deployment using PyCaret.md -> ML
# Updated categories\machine-learning\Model Ensemble.md -> ML
# Updated categories\machine-learning\Model Evaluation vs Model Optimisation.md -> ML
# Updated categories\machine-learning\Model Evaluation.md -> ML
# Updated categories\machine-learning\Model Interpretability.md -> ML
# Updated categories\machine-learning\Model Observability.md -> ML
# Updated categories\machine-learning\Model Optimisation.md -> ML
# Updated categories\machine-learning\Model Parameters Tuning.md -> ML
# Updated categories\machine-learning\Model parameters vs hyperparameters.md -> ML
# Updated categories\machine-learning\Model Parameters.md -> ML
# Updated categories\machine-learning\Model Selection.md -> ML
# Updated categories\machine-learning\Model Validation.md -> ML
# Updated categories\machine-learning\model-agnostic feature importance.md -> ML
# Updated categories\machine-learning\Momentum.md -> ML
# Updated categories\machine-learning\Moving Average Forecast.md -> ML
# Updated categories\machine-learning\Multinomial Naive bayes.md -> ML
# Updated categories\machine-learning\Multiple Linear Regression.md -> ML
# Updated categories\machine-learning\Naive Bayes Classifier.md -> ML
# Updated categories\machine-learning\Naive Forecast.md -> ML
# Updated categories\machine-learning\Neural Network Classification.md -> ML
# Updated categories\machine-learning\Neural network in Practice.md -> ML
# Updated categories\machine-learning\Neural network.md -> ML
# Updated categories\machine-learning\Neural Scaling Laws.md -> ML
# Updated categories\machine-learning\Non-negative matrix factorization in ML.md -> ML
# Updated categories\machine-learning\Non-parametric tests.md -> ML
# Updated categories\machine-learning\Normalisation of data.md -> ML
# Updated categories\machine-learning\Normalisation vs Standardisation.md -> ML
# Updated categories\machine-learning\objective function.md -> ML
# Updated categories\machine-learning\One-hot encoding.md -> ML
# Updated categories\machine-learning\Optimisation function.md -> ML
# Updated categories\machine-learning\Optimisation techniques.md -> ML
# Updated categories\machine-learning\Optimising a Logistic Regression Model.md -> ML
# Updated categories\machine-learning\Optimising Neural Networks.md -> ML
# Updated categories\machine-learning\Optuna.md -> ML
# Updated categories\machine-learning\Ordinary Least Squares.md -> ML
# Updated categories\machine-learning\Orthogonalization.md -> ML
# Updated categories\machine-learning\Outliers.md -> ML
# Updated categories\machine-learning\Over parameterised models.md -> ML
# Updated categories\machine-learning\PCA Explained Variance Ratio.md -> ML
# Updated categories\machine-learning\PCA Principal Components.md -> ML
# Updated categories\machine-learning\PCA-Based Anomaly Detection.md -> ML
# Updated categories\machine-learning\PDP and ICE.md -> ML
# Updated categories\machine-learning\Percentile Detection.md -> ML
# Updated categories\machine-learning\Performance Drift.md -> ML
# Updated categories\machine-learning\Polynomial Regression.md -> ML
# Updated categories\machine-learning\Positional Encoding.md -> ML
# Updated categories\machine-learning\Precision or Recall.md -> ML
# Updated categories\machine-learning\Precision-Recall Curve.md -> ML
# Updated categories\machine-learning\Precision.md -> ML
# Updated categories\machine-learning\Prediction Intervals vs Confidence Interval.md -> ML
# Updated categories\machine-learning\Principal Component Analysis.md -> ML
# Updated categories\machine-learning\PyCaret.md -> ML
# Updated categories\machine-learning\PyOD.md -> ML
# Updated categories\machine-learning\Pytorch vs Tensorflow.md -> ML
# Updated categories\machine-learning\PyTorch.md -> ML
# Updated categories\machine-learning\Q-Learning.md -> ML
# Updated categories\machine-learning\Random Forest for Time Series.md -> ML
# Updated categories\machine-learning\Random Forest.md -> ML
# Updated categories\machine-learning\Recall.md -> ML
# Updated categories\machine-learning\Recommender systems.md -> ML
# Updated categories\machine-learning\Recurrent Neural Networks.md -> ML
# Updated categories\machine-learning\Regression Metrics.md -> ML
# Updated categories\machine-learning\Regression.md -> ML
# Updated categories\machine-learning\Regularisation of Tree based models.md -> ML
# Updated categories\machine-learning\Regularisation.md -> ML
# Updated categories\machine-learning\Reinforcement learning.md -> ML
# Updated categories\machine-learning\Relationships in memory.md -> ML
# Updated categories\machine-learning\Reward Function.md -> ML
# Updated categories\machine-learning\Ridge.md -> ML
# Updated categories\machine-learning\ROC (Receiver Operating Characteristic).md -> ML
# Updated categories\machine-learning\Sammon’s Mapping.md -> ML
# Updated categories\machine-learning\SARIMA.md -> ML
# Updated categories\machine-learning\Scikit-Learn.md -> ML
# Updated categories\machine-learning\Secretary Problem.md -> ML
# Updated categories\machine-learning\semi-structured data.md -> ML
# Updated categories\machine-learning\Sentence Transformers.md -> ML
# Updated categories\machine-learning\Sklearn Pipeline.md -> ML
# Updated categories\machine-learning\Specificity.md -> ML
# Updated categories\machine-learning\Spectral Clustering.md -> ML
# Updated categories\machine-learning\Supervised Learning.md -> ML
# Updated categories\machine-learning\Support Vector Classifier.md -> ML
# Updated categories\machine-learning\Support Vector Machines.md -> ML
# Updated categories\machine-learning\Support Vector Regression.md -> ML
# Updated categories\machine-learning\Tensorflow.md -> ML
# Updated categories\machine-learning\Test Loss When Evaluating Models.md -> ML
# Updated categories\machine-learning\Text Classification.md -> ML
# Updated categories\machine-learning\Time Series Python Packages.md -> ML
# Updated categories\machine-learning\Train-Dev-Test Sets.md -> ML
# Updated categories\machine-learning\Transfer Learning.md -> ML
# Updated categories\machine-learning\Transformed Target Regressor.md -> ML
# Updated categories\machine-learning\Transformer.md -> ML
# Updated categories\machine-learning\Transformers vs RNNs.md -> ML
# Updated categories\machine-learning\Type I Error (False Positive).md -> ML
# Updated categories\machine-learning\Type II Error (False Negative).md -> ML
# Updated categories\machine-learning\Types of Neural Networks.md -> ML
# Updated categories\machine-learning\Typical Output Formats in Neural Networks.md -> ML
# Updated categories\machine-learning\UMAP.md -> ML
# Updated categories\machine-learning\Unsupervised Learning.md -> ML
# Updated categories\machine-learning\Use Cases for a Simple Neural Network Like.md -> ML
# Updated categories\machine-learning\vanishing and exploding gradients problem.md -> ML
# Updated categories\machine-learning\Variability in linear models.md -> ML
# Updated categories\machine-learning\Variance in ML.md -> ML
# Updated categories\machine-learning\Vector Embedding.md -> ML
# Updated categories\machine-learning\WCSS and elbow method.md -> ML
# Updated categories\machine-learning\Weak Learners.md -> ML
# Updated categories\machine-learning\When and why not to us regularisation.md -> ML
# Updated categories\machine-learning\Why does increasing the number of models in a ensemble not necessarily improve the accuracy.md -> ML
# Updated categories\machine-learning\Why does the Adam Optimizer converge.md -> ML
# Updated categories\machine-learning\Why Removing Outliers May Improve Regression but Harm Classification.md -> ML
# Updated categories\machine-learning\Why standardise features.md -> ML
# Updated categories\machine-learning\Why Type 1 and Type 2 matter.md -> ML
# Updated categories\machine-learning\Wrapper Methods.md -> ML
# Updated categories\machine-learning\Xaiver.md -> ML
# Updated categories\machine-learning\XGBoost.md -> ML
# Updated categories\data-engineering\ACID Transaction.md -> DE
# Updated categories\data-engineering\Ada boosting.md -> DE
# Updated categories\data-engineering\Adding a database to PostgreSQL.md -> DE
# Updated categories\data-engineering\Aggregation.md -> DE
# Updated categories\data-engineering\Apache Iceberg.md -> DE
# Updated categories\data-engineering\Attack mitigation.md -> DE
# Updated categories\data-engineering\Attack types.md -> DE
# Updated categories\data-engineering\AWS Lambda.md -> DE
# Updated categories\data-engineering\Azure.md -> DE
# Updated categories\data-engineering\Bagging.md -> DE
# Updated categories\data-engineering\Benefits of Data Transformation.md -> DE
# Updated categories\data-engineering\Big Data.md -> DE
# Updated categories\data-engineering\BigQuery.md -> DE
# Updated categories\data-engineering\Cassandra.md -> DE
# Updated categories\data-engineering\Cloud Providers.md -> DE
# Updated categories\data-engineering\Coaching & Mentoring.md -> DE
# Updated categories\data-engineering\Columnar Storage.md -> DE
# Updated categories\data-engineering\Command Prompt.md -> DE
# Updated categories\data-engineering\Common Table Expression.md -> DE
# Updated categories\data-engineering\Components of the database.md -> DE
# Updated categories\data-engineering\Covering Index.md -> DE
# Updated categories\data-engineering\Crosstab.md -> DE
# Updated categories\data-engineering\CRUD.md -> DE
# Updated categories\data-engineering\CUDA.md -> DE
# Updated categories\data-engineering\Curse of dimensionality.md -> DE
# Updated categories\data-engineering\Cypher.md -> DE
# Updated categories\data-engineering\Data Architect.md -> DE
# Updated categories\data-engineering\Data Architecture.md -> DE
# Updated categories\data-engineering\Data Cleansing.md -> DE
# Updated categories\data-engineering\Data Contract.md -> DE
# Updated categories\data-engineering\Data Deployment.md -> DE
# Updated categories\data-engineering\Data Dictionary.md -> DE
# Updated categories\data-engineering\Data Drift.md -> DE
# Updated categories\data-engineering\Data Engineering Portal.md -> DE
# Updated categories\data-engineering\Data Engineering Tools.md -> DE
# Updated categories\data-engineering\Data Engineering.md -> DE
# Updated categories\data-engineering\Data Evaluation.md -> DE
# Updated categories\data-engineering\Data Hierarchy of Needs.md -> DE
# Updated categories\data-engineering\Data Integration.md -> DE
# Updated categories\data-engineering\Data Integrity.md -> DE
# Updated categories\data-engineering\Data Lake.md -> DE
# Updated categories\data-engineering\Data Lakehouse.md -> DE
# Updated categories\data-engineering\Data Leakage.md -> DE
# Updated categories\data-engineering\Data Lifecycle Management.md -> DE
# Updated categories\data-engineering\data lineage.md -> DE
# Updated categories\data-engineering\Data Management.md -> DE
# Updated categories\data-engineering\Data Modeling.md -> DE
# Updated categories\data-engineering\Data Observability.md -> DE
# Updated categories\data-engineering\Data Principles.md -> DE
# Updated categories\data-engineering\Data Quality.md -> DE
# Updated categories\data-engineering\Data Security.md -> DE
# Updated categories\data-engineering\Data Selection.md -> DE
# Updated categories\data-engineering\Data Sources.md -> DE
# Updated categories\data-engineering\Data Storage.md -> DE
# Updated categories\data-engineering\Data Transformation in Data Engineering.md -> DE
# Updated categories\data-engineering\Data Transformation with Pandas.md -> DE
# Updated categories\data-engineering\Data Transformation.md -> DE
# Updated categories\data-engineering\Data Validation.md -> DE
# Updated categories\data-engineering\Data Virtualization.md -> DE
# Updated categories\data-engineering\Data Warehouse.md -> DE
# Updated categories\data-engineering\Database Index.md -> DE
# Updated categories\data-engineering\Database Management System (DBMS).md -> DE
# Updated categories\data-engineering\Database Storage.md -> DE
# Updated categories\data-engineering\Database Techniques.md -> DE
# Updated categories\data-engineering\Database.md -> DE
# Updated categories\data-engineering\Databricks 1.md -> DE
# Updated categories\data-engineering\DataOps.md -> DE
# Updated categories\data-engineering\dbt 1.md -> DE
# Updated categories\data-engineering\design pattern.md -> DE
# Updated categories\data-engineering\Digital twin.md -> DE
# Updated categories\data-engineering\Distributed Computing.md -> DE
# Updated categories\data-engineering\DuckDB in python.md -> DE
# Updated categories\data-engineering\DuckDB vs SQLite.md -> DE
# Updated categories\data-engineering\Durability.md -> DE
# Updated categories\data-engineering\ELT.md -> DE
# Updated categories\data-engineering\Estimator.md -> DE
# Updated categories\data-engineering\ETL 1.md -> DE
# Updated categories\data-engineering\ETL Pipeline Example.md -> DE
# Updated categories\data-engineering\ETL vs ELT.md -> DE
# Updated categories\data-engineering\ETL.md -> DE
# Updated categories\data-engineering\EtLT.md -> DE
# Updated categories\data-engineering\Event Driven Microservices.md -> DE
# Updated categories\data-engineering\Event-Driven Architecture.md -> DE
# Updated categories\data-engineering\Fabric.md -> DE
# Updated categories\data-engineering\Faker.md -> DE
# Updated categories\data-engineering\File Management.md -> DE
# Updated categories\data-engineering\Folder Tree Diagram.md -> DE
# Updated categories\data-engineering\Foreign Key.md -> DE
# Updated categories\data-engineering\Github Actions.md -> DE
# Updated categories\data-engineering\Google Sheet Pivots Table.md -> DE
# Updated categories\data-engineering\Grain.md -> DE
# Updated categories\data-engineering\Graph Query Language.md -> DE
# Updated categories\data-engineering\Groupby vs Crosstab.md -> DE
# Updated categories\data-engineering\Groupby.md -> DE
# Updated categories\data-engineering\heterogeneous features.md -> DE
# Updated categories\data-engineering\Honkit.md -> DE
# Updated categories\data-engineering\Hosting.md -> DE
# Updated categories\data-engineering\How is schema evolution done in practice with SQL.md -> DE
# Updated categories\data-engineering\How to normalise a merged table.md -> DE
# Updated categories\data-engineering\Implementing Database Schema.md -> DE
# Updated categories\data-engineering\Imputation Techniques.md -> DE
# Updated categories\data-engineering\in-memory format.md -> DE
# Updated categories\data-engineering\incremental synchronization.md -> DE
# Updated categories\data-engineering\Indexing in cypher.md -> DE
# Updated categories\data-engineering\Input is Not Properly Sanitized.md -> DE
# Updated categories\data-engineering\Joining Datasets.md -> DE
# Updated categories\data-engineering\Junction Tables.md -> DE
# Updated categories\data-engineering\KNIME.md -> DE
# Updated categories\data-engineering\Logical Model.md -> DE
# Updated categories\data-engineering\Many-to-Many Relationships.md -> DE
# Updated categories\data-engineering\map reduce.md -> DE
# Updated categories\data-engineering\MariaDB.md -> DE
# Updated categories\data-engineering\master data management.md -> DE
# Updated categories\data-engineering\Merge.md -> DE
# Updated categories\data-engineering\Microsoft Access.md -> DE
# Updated categories\data-engineering\Missing Data.md -> DE
# Updated categories\data-engineering\Model Deployment.md -> DE
# Updated categories\data-engineering\Monolith Architecture.md -> DE
# Updated categories\data-engineering\Multi-level index.md -> DE
# Updated categories\data-engineering\Multiprocessing.md -> DE
# Updated categories\data-engineering\MySql.md -> DE
# Updated categories\data-engineering\neo4j.md -> DE
# Updated categories\data-engineering\Normalised Schema.md -> DE
# Updated categories\data-engineering\NoSQL.md -> DE
# Updated categories\data-engineering\Object Relational Mapper.md -> DE
# Updated categories\data-engineering\OLTP.md -> DE
# Updated categories\data-engineering\Overfitting.md -> DE
# Updated categories\data-engineering\Pandas join vs merge.md -> DE
# Updated categories\data-engineering\Pandas Pivot Table.md -> DE
# Updated categories\data-engineering\Pandas Stack.md -> DE
# Updated categories\data-engineering\Pandas.md -> DE
# Updated categories\data-engineering\pd.Grouper.md -> DE
# Updated categories\data-engineering\Pgadmin Permissions on Windows.md -> DE
# Updated categories\data-engineering\pgAdmin.md -> DE
# Updated categories\data-engineering\Physical Model.md -> DE
# Updated categories\data-engineering\Pickle.md -> DE
# Updated categories\data-engineering\Poetry.md -> DE
# Updated categories\data-engineering\Polars.md -> DE
# Updated categories\data-engineering\PostgreSQL.md -> DE
# Updated categories\data-engineering\Postman.md -> DE
# Updated categories\data-engineering\PowerShell.md -> DE
# Updated categories\data-engineering\Prevention Is Better Than The Cure.md -> DE
# Updated categories\data-engineering\Primary Key.md -> DE
# Updated categories\data-engineering\Push-Down.md -> DE
# Updated categories\data-engineering\Pydantic.md -> DE
# Updated categories\data-engineering\Pyright vs Pydantic.md -> DE
# Updated categories\data-engineering\Query Optimisation.md -> DE
# Updated categories\data-engineering\Querying Time Series.md -> DE
# Updated categories\data-engineering\Querying.md -> DE
# Updated categories\data-engineering\Race Conditions.md -> DE
# Updated categories\data-engineering\Relating Tables Together.md -> DE
# Updated categories\data-engineering\Relational Database.md -> DE
# Updated categories\data-engineering\reverse etl.md -> DE
# Updated categories\data-engineering\rollup.md -> DE
# Updated categories\data-engineering\Row parameters in SQL.md -> DE
# Updated categories\data-engineering\Row-based Storage.md -> DE
# Updated categories\data-engineering\Scalability.md -> DE
# Updated categories\data-engineering\Scaling Server.md -> DE
# Updated categories\data-engineering\Schema Evolution.md -> DE
# Updated categories\data-engineering\Search.md -> DE
# Updated categories\data-engineering\Security mitigation.md -> DE
# Updated categories\data-engineering\Security Researcher.md -> DE
# Updated categories\data-engineering\semantic layer.md -> DE
# Updated categories\data-engineering\Single Source of Truth.md -> DE
# Updated categories\data-engineering\Sklearn Pipiline.md -> DE
# Updated categories\data-engineering\Slowly Changing Dimension.md -> DE
# Updated categories\data-engineering\SMSS.md -> DE
# Updated categories\data-engineering\Snowflake Schema.md -> DE
# Updated categories\data-engineering\Soft Deletion.md -> DE
# Updated categories\data-engineering\Software Design Patterns.md -> DE
# Updated categories\data-engineering\Spreadsheets vs Databases.md -> DE
# Updated categories\data-engineering\SQL Groupby.md -> DE
# Updated categories\data-engineering\SQL Injection.md -> DE
# Updated categories\data-engineering\SQL Joins.md -> DE
# Updated categories\data-engineering\SQL.md -> DE
# Updated categories\data-engineering\SQLAlchemy vs. sqlite3.md -> DE
# Updated categories\data-engineering\SQLAlchemy.md -> DE
# Updated categories\data-engineering\SQLite Studio.md -> DE
# Updated categories\data-engineering\SQLite.md -> DE
# Updated categories\data-engineering\Star Schema.md -> DE
# Updated categories\data-engineering\storage layer object store.md -> DE
# Updated categories\data-engineering\structured data.md -> DE
# Updated categories\data-engineering\Structuring and organizing data.md -> DE
# Updated categories\data-engineering\Transaction.md -> DE
# Updated categories\data-engineering\Turning a flat file into a database.md -> DE
# Updated categories\data-engineering\Types of Database Schema.md -> DE
# Updated categories\data-engineering\Unix.md -> DE
# Updated categories\data-engineering\unstructured data.md -> DE
# Updated categories\data-engineering\Usability.md -> DE
# Updated categories\data-engineering\Vacuum.md -> DE
# Updated categories\data-engineering\Vector Database.md -> DE
# Updated categories\data-engineering\Vectorized Engine.md -> DE
# Updated categories\data-engineering\View Use Case.md -> DE
# Updated categories\data-engineering\Views.md -> DE
# Updated categories\data-engineering\Windows Subsystem for Linux.md -> DE
# Updated categories\statistics\Addressing Multicollinearity.md -> STATISTICS
# Updated categories\statistics\ANOVA.md -> STATISTICS
# Updated categories\statistics\Assumption of Normality.md -> STATISTICS
# Updated categories\statistics\Bernoulli.md -> STATISTICS
# Updated categories\statistics\Bootstrap Sampling.md -> STATISTICS
# Updated categories\statistics\Casual Inference.md -> STATISTICS
# Updated categories\statistics\Central Limit Theorem & Small Sample Sizes.md -> STATISTICS
# Updated categories\statistics\Central Limit Theorem.md -> STATISTICS
# Updated categories\statistics\Chi-Squared Test.md -> STATISTICS
# Updated categories\statistics\Confidence Interval.md -> STATISTICS
# Updated categories\statistics\Correlation vs Causation.md -> STATISTICS
# Updated categories\statistics\Correlation.md -> STATISTICS
# Updated categories\statistics\Cosine Similarity.md -> STATISTICS
# Updated categories\statistics\Covariance vs Correlation.md -> STATISTICS
# Updated categories\statistics\Covariance.md -> STATISTICS
# Updated categories\statistics\Cryptography.md -> STATISTICS
# Updated categories\statistics\Differentation.md -> STATISTICS
# Updated categories\statistics\Distributions.md -> STATISTICS
# Updated categories\statistics\EM Algorithm.md -> STATISTICS
# Updated categories\statistics\Factor Analysis.md -> STATISTICS
# Updated categories\statistics\Gaussian Distribution.md -> STATISTICS
# Updated categories\statistics\Graph Theory.md -> STATISTICS
# Updated categories\statistics\Grouped plots.md -> STATISTICS
# Updated categories\statistics\Handling Different Distributions.md -> STATISTICS
# Updated categories\statistics\Hypothesis testing.md -> STATISTICS
# Updated categories\statistics\information theory.md -> STATISTICS
# Updated categories\statistics\Interquartile Range (IQR) Detection.md -> STATISTICS
# Updated categories\statistics\Johnson–Lindenstrauss lemma.md -> STATISTICS
# Updated categories\statistics\Markov chain.md -> STATISTICS
# Updated categories\statistics\Mathematics.md -> STATISTICS
# Updated categories\statistics\Mean Absolute Error.md -> STATISTICS
# Updated categories\statistics\Mean Squared Error.md -> STATISTICS
# Updated categories\statistics\mean vs median.md -> STATISTICS
# Updated categories\statistics\Multicollinearity.md -> STATISTICS
# Updated categories\statistics\non-parametric.md -> STATISTICS
# Updated categories\statistics\Odds vs Probability.md -> STATISTICS
# Updated categories\statistics\Odds.md -> STATISTICS
# Updated categories\statistics\p values.md -> STATISTICS
# Updated categories\statistics\Parametric tests.md -> STATISTICS
# Updated categories\statistics\parametric vs non-parametric models.md -> STATISTICS
# Updated categories\statistics\parametric vs non-parametric tests.md -> STATISTICS
# Updated categories\statistics\parsimonious.md -> STATISTICS
# Updated categories\statistics\Prediction Intervals.md -> STATISTICS
# Updated categories\statistics\Probability.md -> STATISTICS
# Updated categories\statistics\Proportion Test.md -> STATISTICS
# Updated categories\statistics\Q-Q Plot.md -> STATISTICS
# Updated categories\statistics\R squared.md -> STATISTICS
# Updated categories\statistics\R-squared metric not always a good indicator of model performance in regression.md -> STATISTICS
# Updated categories\statistics\R.md -> STATISTICS
# Updated categories\statistics\Reasoning tokens.md -> STATISTICS
# Updated categories\statistics\Root Mean Squared Error.md -> STATISTICS
# Updated categories\statistics\Sampling.md -> STATISTICS
# Updated categories\statistics\Spearman vs Pearson Correlation.md -> STATISTICS
# Updated categories\statistics\Standard deviation.md -> STATISTICS
# Updated categories\statistics\Standardisation.md -> STATISTICS
# Updated categories\statistics\Statistical Assumptions.md -> STATISTICS
# Updated categories\statistics\Statistical Tests.md -> STATISTICS
# Updated categories\statistics\Statistical theorems.md -> STATISTICS
# Updated categories\statistics\Statistics.md -> STATISTICS
# Updated categories\statistics\statsmodels.md -> STATISTICS
# Updated categories\statistics\Stochastic Gradient Descent.md -> STATISTICS
# Updated categories\statistics\Symbolic computation.md -> STATISTICS
# Updated categories\statistics\Sympy.md -> STATISTICS
# Updated categories\statistics\T-test.md -> STATISTICS
# Updated categories\statistics\univariate vs multivariate.md -> STATISTICS
# Updated categories\statistics\Variance.md -> STATISTICS
# Updated categories\statistics\Violin plot.md -> STATISTICS
# Updated categories\statistics\Z-Normalisation.md -> STATISTICS
# Updated categories\statistics\Z-Score.md -> STATISTICS
# Updated categories\statistics\Z-Scores vs Prediction Intervals.md -> STATISTICS
# Updated categories\statistics\Z-Test.md -> STATISTICS
# Updated categories\computer-science\Algorithms.md -> CS
# Updated categories\computer-science\Big O Notation.md -> CS
# Updated categories\computer-science\BM25 (Best Match 25).md -> CS
# Updated categories\computer-science\Checksum.md -> CS
# Updated categories\computer-science\Computer Science.md -> CS
# Updated categories\computer-science\Concurrency.md -> CS
# Updated categories\computer-science\Convex Optimisation.md -> CS
# Updated categories\computer-science\csv module.md -> CS
# Updated categories\computer-science\Directed Acyclic Graph (DAG).md -> CS
# Updated categories\computer-science\Flask.md -> CS
# Updated categories\computer-science\garbage collector.md -> CS
# Updated categories\computer-science\Generators in Python.md -> CS
# Updated categories\computer-science\Hash.md -> CS
# Updated categories\computer-science\Heap Data Structure.md -> CS
# Updated categories\computer-science\Heap Memory.md -> CS
# Updated categories\computer-science\How to search within a graph.md -> CS
# Updated categories\computer-science\Immutable vs mutable.md -> CS
# Updated categories\computer-science\Java vs JavaScript.md -> CS
# Updated categories\computer-science\Java.md -> CS
# Updated categories\computer-science\JavaScript.md -> CS
# Updated categories\computer-science\Knowledge Graph.md -> CS
# Updated categories\computer-science\Langchain.md -> CS
# Updated categories\computer-science\Machine Learning Algorithms.md -> CS
# Updated categories\computer-science\Monte Carlo Simulation.md -> CS
# Updated categories\computer-science\Multiprocessing vs Multithreading.md -> CS
# Updated categories\computer-science\Multithreading.md -> CS
# Updated categories\computer-science\neomodel.md -> CS
# Updated categories\computer-science\Node.JS.md -> CS
# Updated categories\computer-science\Numpy.md -> CS
# Updated categories\computer-science\Processes vs Threads.md -> CS
# Updated categories\computer-science\programming languages.md -> CS
# Updated categories\computer-science\PyGraphviz.md -> CS
# Updated categories\computer-science\QuickSort.md -> CS
# Updated categories\computer-science\Ranking models.md -> CS
# Updated categories\computer-science\Recursive Algorithm.md -> CS
# Updated categories\computer-science\Stored Procedures.md -> CS
# Updated categories\computer-science\Strongly vs Weakly typed language.md -> CS
# Updated categories\computer-science\Times Series Python Packages.md -> CS
# Updated categories\natural-language\AI Agents Memory.md -> LANG
# Updated categories\natural-language\Attention mechanism.md -> LANG
# Updated categories\natural-language\Bag of words.md -> LANG
# Updated categories\natural-language\BERT.md -> LANG
# Updated categories\natural-language\BERTScore.md -> LANG
# Updated categories\natural-language\Chain of thought.md -> LANG
# Updated categories\natural-language\ChatGPT.md -> LANG
# Updated categories\natural-language\Claude.md -> LANG
# Updated categories\natural-language\Comparing LLMs.md -> LANG
# Updated categories\natural-language\Distillation.md -> LANG
# Updated categories\natural-language\ElasticSearch.md -> LANG
# Updated categories\natural-language\Embedded Methods.md -> LANG
# Updated categories\natural-language\embeddings for OOV words.md -> LANG
# Updated categories\natural-language\Evaluate Embedding Methods.md -> LANG
# Updated categories\natural-language\Fuzzywuzzy.md -> LANG
# Updated categories\natural-language\Generative AI From Theory to Practice.md -> LANG
# Updated categories\natural-language\Generative AI.md -> LANG
# Updated categories\natural-language\Grammar method.md -> LANG
# Updated categories\natural-language\Guardrails.md -> LANG
# Updated categories\natural-language\How businesses use Gen AI.md -> LANG
# Updated categories\natural-language\How LLMs store facts.md -> LANG
# Updated categories\natural-language\How to reduce the need for Gen AI responses.md -> LANG
# Updated categories\natural-language\How would you decide between using TF-IDF and Word2Vec for text vectorization.md -> LANG
# Updated categories\natural-language\In NER how would you handle ambiguous entities.md -> LANG
# Updated categories\natural-language\Key Components of Attention and Formula.md -> LANG
# Updated categories\natural-language\Knowledge graph vs RAG setup.md -> LANG
# Updated categories\natural-language\Language Model Output Optimisation.md -> LANG
# Updated categories\natural-language\Language Models Large (LLMs) vs Small (SLMs).md -> LANG
# Updated categories\natural-language\Language Models.md -> LANG
# Updated categories\natural-language\lemmatization.md -> LANG
# Updated categories\natural-language\LLM Memory.md -> LANG
# Updated categories\natural-language\LLM.md -> LANG
# Updated categories\natural-language\Local LLM use cases.md -> LANG
# Updated categories\natural-language\Mathematical Reasoning in Transformers.md -> LANG
# Updated categories\natural-language\Mixture of Experts.md -> LANG
# Updated categories\natural-language\Model Cascading.md -> LANG
# Updated categories\natural-language\Multi-head attention.md -> LANG
# Updated categories\natural-language\Named Entity Recognition.md -> LANG
# Updated categories\natural-language\NER Implementation.md -> LANG
# Updated categories\natural-language\Ngrams.md -> LANG
# Updated categories\natural-language\NLP.md -> LANG
# Updated categories\natural-language\nltk.md -> LANG
# Updated categories\natural-language\Non-negative Matrix Factorization.md -> LANG
# Updated categories\natural-language\NotebookLM.md -> LANG
# Updated categories\natural-language\OOV words.md -> LANG
# Updated categories\natural-language\Pandas Dataframe Agent.md -> LANG
# Updated categories\natural-language\Part of speech tagging.md -> LANG
# Updated categories\natural-language\Prompt Engineering.md -> LANG
# Updated categories\natural-language\prompt retrievers.md -> LANG
# Updated categories\natural-language\Prompts.md -> LANG
# Updated categories\natural-language\Pyright.md -> LANG
# Updated categories\natural-language\RAG.md -> LANG
# Updated categories\natural-language\Scaling Agentic Systems.md -> LANG
# Updated categories\natural-language\Self attention vs multi-head attention.md -> LANG
# Updated categories\natural-language\Self-Attention.md -> LANG
# Updated categories\natural-language\Semantic Relationships.md -> LANG
# Updated categories\natural-language\Semantic search.md -> LANG
# Updated categories\natural-language\Sentence Similarity.md -> LANG
# Updated categories\natural-language\Sentence Transformer Workflow.md -> LANG
# Updated categories\natural-language\Similarity Search.md -> LANG
# Updated categories\natural-language\Small Language Models.md -> LANG
# Updated categories\natural-language\spaCy.md -> LANG
# Updated categories\natural-language\Stemming.md -> LANG
# Updated categories\natural-language\stopwords.md -> LANG
# Updated categories\natural-language\Summarisation.md -> LANG
# Updated categories\natural-language\syntactic relationships.md -> LANG
# Updated categories\natural-language\Text2Cypher.md -> LANG
# Updated categories\natural-language\TF-IDF Implementation.md -> LANG
# Updated categories\natural-language\TF-IDF.md -> LANG
# Updated categories\natural-language\Tokenisation.md -> LANG
# Updated categories\natural-language\topic modeling.md -> LANG
# Updated categories\natural-language\Vectorisation.md -> LANG
# Updated categories\natural-language\Why is named entity recognition (NER) a challenging task.md -> LANG
# Updated categories\natural-language\Word2vec.md -> LANG
# Updated categories\natural-language\WordNet.md -> LANG
# Updated categories\devops\AB testing.md -> DEVOPS
# ...
# Updated categories\devops\dagster.md -> DEVOPS
# Updated categories\devops\Data Ingestion.md -> DEVOPS
# Updated categories\devops\Data Orchestration.md -> DEVOPS
# Updated categories\devops\Data Pipeline to Data Products.md -> DEVOPS
# Updated categories\devops\Data Pipeline.md -> DEVOPS
# Updated categories\devops\Data Streaming.md -> DEVOPS
# Updated categories\devops\Databricks vs Snowflake.md -> DEVOPS
# Updated categories\devops\Databricks.md -> DEVOPS
# Updated categories\devops\dbt.md -> DEVOPS
# Updated categories\devops\Debugging.md -> DEVOPS
# Updated categories\devops\Declarative Data Pipeline.md -> DEVOPS
# Updated categories\devops\dependency manager.md -> DEVOPS
# Updated categories\devops\DevOps.md -> DEVOPS
# Updated categories\devops\Digital Transformation.md -> DEVOPS
# Updated categories\devops\Docker Image.md -> DEVOPS
# Updated categories\devops\Docker.md -> DEVOPS
# Updated categories\devops\Elastic Net.md -> DEVOPS
# Updated categories\devops\Environment Variables.md -> DEVOPS
# Updated categories\devops\Epub.md -> DEVOPS
# Updated categories\devops\Event Driven Events.md -> DEVOPS
# Updated categories\devops\Event Driven.md -> DEVOPS
# Updated categories\devops\Everything.md -> DEVOPS
# Updated categories\devops\Excel 1.md -> DEVOPS
# Updated categories\devops\Excel pivot table.md -> DEVOPS
# Updated categories\devops\Excel vs Google Sheets.md -> DEVOPS
# Updated categories\devops\Excel.md -> DEVOPS
# Updated categories\devops\FastAPI.md -> DEVOPS
# Updated categories\devops\Firebase.md -> DEVOPS
# Updated categories\devops\frontend.md -> DEVOPS
# Updated categories\devops\functional programming.md -> DEVOPS
# Updated categories\devops\GIS.md -> DEVOPS
# Updated categories\devops\Git.md -> DEVOPS
# Updated categories\devops\Github Gists.md -> DEVOPS
# Updated categories\devops\gitlab-ci.yml.md -> DEVOPS
# Updated categories\devops\Global Interpreter Lock.md -> DEVOPS
# Updated categories\devops\Google Cloud Platform.md -> DEVOPS
# Updated categories\devops\Google Colab.md -> DEVOPS
# Updated categories\devops\Google My Maps Data Extraction.md -> DEVOPS
# Updated categories\devops\Google Sheets.md -> DEVOPS
# Updated categories\devops\GPT.md -> DEVOPS
# Updated categories\devops\Gradio.md -> DEVOPS
# Updated categories\devops\Grep.md -> DEVOPS
# Updated categories\devops\Hadoop.md -> DEVOPS
# Updated categories\devops\Hugging Face.md -> DEVOPS
# Updated categories\devops\imperative.md -> DEVOPS
# Updated categories\devops\ipynb.md -> DEVOPS
# Updated categories\devops\jinja template.md -> DEVOPS
# Updated categories\devops\Json to SQLite.md -> DEVOPS
# Updated categories\devops\Json.md -> DEVOPS
# Updated categories\devops\jupytext.md -> DEVOPS
# Updated categories\devops\Justfile.md -> DEVOPS
# Updated categories\devops\kubernetes.md -> DEVOPS
# Updated categories\devops\Load Balancing.md -> DEVOPS
# Updated categories\devops\Maintainability.md -> DEVOPS
# Updated categories\devops\Maintainable Code.md -> DEVOPS
# Updated categories\devops\Makefile.md -> DEVOPS
# Updated categories\devops\Master Observability Datadog.md -> DEVOPS
# Updated categories\devops\Memory Caching.md -> DEVOPS
# Updated categories\devops\Memory.md -> DEVOPS
# Updated categories\devops\Microsoft.md -> DEVOPS
# Updated categories\devops\MongoDB.md -> DEVOPS
# Updated categories\devops\nbconvert.md -> DEVOPS
# Updated categories\devops\NET.md -> DEVOPS
# Updated categories\devops\Normalisation of Text.md -> DEVOPS
# Updated categories\devops\Pandas Series vs DataFrame.md -> DEVOPS
# Updated categories\devops\Pandoc.md -> DEVOPS
# Updated categories\devops\PMML.md -> DEVOPS
# Updated categories\devops\Powerquery.md -> DEVOPS
# Updated categories\devops\Powershell scripts.md -> DEVOPS
# Updated categories\devops\Powershell versus Command Prompt.md -> DEVOPS
# Updated categories\devops\Powershell vs Bash.md -> DEVOPS
# Updated categories\devops\Publish and Subscribe.md -> DEVOPS
# Updated categories\devops\PySpark.md -> DEVOPS
# Updated categories\devops\Pytest.md -> DEVOPS
# Updated categories\devops\Python Click.md -> DEVOPS
# Updated categories\devops\Python.md -> DEVOPS
# Updated categories\devops\Quartz.md -> DEVOPS
# Updated categories\devops\Random Access Memory.md -> DEVOPS
# Updated categories\devops\React.md -> DEVOPS
# Updated categories\devops\Registering a Scheduled Task.md -> DEVOPS
# Updated categories\devops\REST API.md -> DEVOPS
# Updated categories\devops\Scala.md -> DEVOPS
# Updated categories\devops\Security Vulnerabilities.md -> DEVOPS
# Updated categories\devops\shapefile.md -> DEVOPS
# Updated categories\devops\Sharepoint.md -> DEVOPS
# Updated categories\devops\Snowflake vs Hadoop.md -> DEVOPS
# Updated categories\devops\Snowflake.md -> DEVOPS
# Updated categories\devops\Software Development Life Cycle.md -> DEVOPS
# Updated categories\devops\Software Development Portal.md -> DEVOPS
# Updated categories\devops\SQL vs NoSQL.md -> DEVOPS
# Updated categories\devops\Streamlit.md -> DEVOPS
# Updated categories\devops\Technical Design Doc Template.md -> DEVOPS
# Updated categories\devops\Terminal commands.md -> DEVOPS
# Updated categories\devops\Testing.md -> DEVOPS
# Updated categories\devops\TOML.md -> DEVOPS
# Updated categories\devops\tool.bandit.md -> DEVOPS
# Updated categories\devops\tool.ruff.md -> DEVOPS
# Updated categories\devops\tool.uv.md -> DEVOPS
# Updated categories\devops\Types of Computational Bugs.md -> DEVOPS
# Updated categories\devops\TypeScript.md -> DEVOPS
# Updated categories\devops\Ubuntu.md -> DEVOPS
# Updated categories\devops\unittest.md -> DEVOPS
# Updated categories\devops\Vercel.md -> DEVOPS
# Updated categories\devops\Virtual environments.md -> DEVOPS
# Updated categories\devops\Web Feature Server (WFS).md -> DEVOPS
# Updated categories\devops\Web Map Tile Service (WMTS).md -> DEVOPS
# Updated categories\devops\Why JSON is Better than Pickle for Untrusted Data.md -> DEVOPS
# Updated categories\devops\Windows Scheduled Tasks.md -> DEVOPS
# Updated categories\devops\Windows.md -> DEVOPS
# Updated categories\devops\yaml.md -> DEVOPS
# Updated categories\project-management\1-on-1 Template.md -> PM
# Updated categories\project-management\1-to-1's with a Line Manager.md -> PM
# Updated categories\project-management\Asking questions.md -> PM
# Updated categories\project-management\Change Management.md -> PM
# Updated categories\project-management\Communication principles.md -> PM
# Updated categories\project-management\Communication Techniques.md -> PM
# Updated categories\project-management\Communication with Stakeholders.md -> PM
# Updated categories\project-management\Conceptual Model.md -> PM
# Updated categories\project-management\Documentation.md -> PM
# Updated categories\project-management\Education and Training.md -> PM
# Updated categories\project-management\Experiment Plan Template.md -> PM
# Updated categories\project-management\Feedback Template.md -> PM
# Updated categories\project-management\Fishbone diagram.md -> PM
# Updated categories\project-management\How to do git commit messages properly.md -> PM
# Updated categories\project-management\html.md -> PM
# Updated categories\project-management\Jobs to be done.md -> PM
# Updated categories\project-management\Jupyter Book.md -> PM
# Updated categories\project-management\Managing Data Science Teams.md -> PM
# Updated categories\project-management\Modern data team.md -> PM
# Updated categories\project-management\nbconvert slideshows.md -> PM
# Updated categories\project-management\One Pager Template.md -> PM
# Updated categories\project-management\pdoc.md -> PM
# Updated categories\project-management\Problem Definition.md -> PM
# Updated categories\project-management\Process for prototyping.md -> PM
# Updated categories\project-management\Project Management Portal.md -> PM
# Updated categories\project-management\project management.md -> PM
# Updated categories\project-management\Pull Request Template.md -> PM
# Updated categories\project-management\RACI.md -> PM
# Updated categories\project-management\Remaining useful life models.md -> PM
# Updated categories\project-management\Return of Experience Form.md -> PM
# Updated categories\project-management\Reveal.js.md -> PM
# Updated categories\project-management\Technical Debt.md -> PM
# Updated categories\project-management\UML.md -> PM
# Updated categories\project-management\Why use ER diagrams.md -> PM
# Updated categories\industry\AI Engineer.md -> INDUSTRY
# Updated categories\industry\AI governance.md -> INDUSTRY
# Updated categories\industry\Analytics Engineer.md -> INDUSTRY
# Updated categories\industry\business intelligence.md -> INDUSTRY
# Updated categories\industry\Business observability.md -> INDUSTRY
# Updated categories\industry\Business Understanding.md -> INDUSTRY
# Updated categories\industry\Business Values.md -> INDUSTRY
# Updated categories\industry\Data AI Education at Work.md -> INDUSTRY
# Updated categories\industry\Data Engineer.md -> INDUSTRY
# Updated categories\industry\Data Governance.md -> INDUSTRY
# Updated categories\industry\data literacy.md -> INDUSTRY
# Updated categories\industry\Data Roles.md -> INDUSTRY
# Updated categories\industry\Data Steward.md -> INDUSTRY
# Updated categories\industry\Design Thinking Questions.md -> INDUSTRY
# Updated categories\industry\Documentation & Meetings.md -> INDUSTRY
# Updated categories\industry\Energy ABM.md -> INDUSTRY
# Updated categories\industry\Energy Demand Forecasting.md -> INDUSTRY
# Updated categories\industry\Energy Storage.md -> INDUSTRY
# Updated categories\industry\Energy.md -> INDUSTRY
# Updated categories\industry\Facts.md -> INDUSTRY
# Updated categories\industry\Gartner Hype Cycle.md -> INDUSTRY
# Updated categories\industry\Industries of interest.md -> INDUSTRY
# Updated categories\industry\Knowledge Work.md -> INDUSTRY
# Updated categories\industry\Managing People.md -> INDUSTRY
# Updated categories\industry\ML Engineer.md -> INDUSTRY
# Updated categories\industry\Network Design.md -> INDUSTRY
# Updated categories\industry\Operational Resilience for Growth and Adaptability.md -> INDUSTRY
# Updated categories\industry\Reporting.md -> INDUSTRY
# Updated categories\industry\Scaling Data Science Capability.md -> INDUSTRY
# Updated categories\industry\Smart Grids.md -> INDUSTRY
# Updated categories\industry\Telecommunications.md -> INDUSTRY
# Updated categories\industry\Thinking Systems.md -> INDUSTRY
# Updated categories\industry\Use of RNNs in energy sector.md -> INDUSTRY
# Updated categories\industry\Working with SMEs.md -> INDUSTRY
# Updated categories\data-analysis\altair versus seaborn.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Altair.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Binder.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Boxplot.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Dash.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Dashboarding.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Dashboards.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Analysis Portal.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Analysis.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Analyst.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Distribution.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Mining.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Product.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Reduction.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Data Visualisation.md -> DATA_ANALYSIS
# Updated categories\data-analysis\DuckDB.md -> DATA_ANALYSIS
# Updated categories\data-analysis\EDA.md -> DATA_ANALYSIS
# Updated categories\data-analysis\ER Diagrams.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Heatmap.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Label encoding.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Linear Discriminant Analysis.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Log transformation.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Looker Studio.md -> DATA_ANALYSIS
# Updated categories\data-analysis\MariaDB vs MySQL.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Melt.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Multiple Correspondence Analysis.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Multivariate Analysis.md -> DATA_ANALYSIS
# Updated categories\data-analysis\OLAP (online analytical processing).md -> DATA_ANALYSIS
# Updated categories\data-analysis\Page Rank.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Parquet.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Plotly.md -> DATA_ANALYSIS
# Updated categories\data-analysis\PowerBI.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Preprocessing Text Classification.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Preprocessing.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Seaborn.md -> DATA_ANALYSIS
# Updated categories\data-analysis\SQL Window functions.md -> DATA_ANALYSIS
# Updated categories\data-analysis\t-SNE.md -> DATA_ANALYSIS
# Updated categories\data-analysis\Tableau.md -> DATA_ANALYSIS
# Updated categories\deep-learning\Convolutional Neural Networks.md -> DL
# Updated categories\deep-learning\Deep Learning.md -> DL
# Updated categories\deep-learning\How is reinforcement learning being combined with deep learning.md -> DL
# Updated categories\deep-learning\LSTM.md -> DL
# Updated categories\deep-learning\Multi-Agent Reinforcement Learning.md -> DL
# Updated categories\deep-learning\Policy.md -> DL
# Updated categories\deep-learning\Relu.md -> DL
# Updated categories\deep-learning\Sarsa.md -> DL
# Updated categories\OTHER\Addressing_Multicollinearity.py.md -> OTHER
# Updated categories\OTHER\Bag_of_Words.py.md -> OTHER
# Updated categories\OTHER\Bandit example output.md -> OTHER
# Updated categories\OTHER\Bandit_Example_Fixed.py.md -> OTHER
# Updated categories\OTHER\Click_Implementation.py.md -> OTHER
# Updated categories\OTHER\Comparing_Ensembles.py.md -> OTHER
# Updated categories\OTHER\Cross_Entropy.py.md -> OTHER
# Updated categories\OTHER\Cross_Entropy_Single.py.md -> OTHER
# Updated categories\OTHER\Debugging.py.md -> OTHER
# Updated categories\OTHER\Distribution_Analysis.py.md -> OTHER
# Updated categories\OTHER\Factor_Analysis.py.md -> OTHER
# Updated categories\OTHER\FastAPI_Example.py.md -> OTHER
# Updated categories\OTHER\Feature_Distribution.py.md -> OTHER
# Updated categories\OTHER\Forecasting_AutoArima.py.md -> OTHER
# Updated categories\OTHER\Forecasting_Baseline.py.md -> OTHER
# Updated categories\OTHER\Forecasting_Exponential_Smoothing.py.md -> OTHER
# Updated categories\OTHER\Gaussian_Mixture_Model_Implementation.py.md -> OTHER
# Updated categories\OTHER\Handling_Missing_Data.ipynb.md -> OTHER
# Updated categories\OTHER\Handling_Missing_Data_Basic.ipynb.md -> OTHER
# Updated categories\OTHER\Heatmaps_Dendrograms.py.md -> OTHER
# Updated categories\OTHER\Imbalanced_Datasets_SMOTE.py.md -> OTHER
# Updated categories\OTHER\K_Means.py.md -> OTHER
# Updated categories\OTHER\Momentum.py.md -> OTHER
# Updated categories\OTHER\One_hot_encoding.py.md -> OTHER
# Updated categories\OTHER\Pandas_Common.py.md -> OTHER
# Updated categories\OTHER\Pandas_Stack.py.md -> OTHER
# Updated categories\OTHER\PCA_Analysis.ipynb.md -> OTHER
# Updated categories\OTHER\PCA_Based_Anomaly_Detection.py.md -> OTHER
# Updated categories\OTHER\Pycaret_Anomaly.ipynb.md -> OTHER
# Updated categories\OTHER\Pycaret_Example.py.md -> OTHER
# Updated categories\OTHER\Pydantic.py.md -> OTHER
# Updated categories\OTHER\Pydantic_More.py.md -> OTHER
# Updated categories\OTHER\Regression_Logistic_Metrics.ipynb.md -> OTHER
# Updated categories\OTHER\Regularisation.py.md -> OTHER
# Updated categories\OTHER\ROC_Curve.py.md -> OTHER
# Updated categories\OTHER\SVM_Example.py.md -> OTHER
# Updated categories\OTHER\Testing_Pytest.py.md -> OTHER
# Updated categories\OTHER\Testing_unittest.py.md -> OTHER
# Updated categories\OTHER\transfer_learning.py.md -> OTHER
# Updated categories\OTHER\TS_Anomaly_Detection.py.md -> OTHER
# Updated categories\OTHER\Vector_Embedding.py.md -> OTHER
# Updated categories\OTHER\Wikipedia_API.py.md -> OTHER
# Updated categories\OTHER\Word2Vec.py.md -> OTHER
# Updated categories\PAPER\Attention Is All You Need.md -> PAPER
# Updated categories\PAPER\BERT Pretraining of Deep Bidirectional Transformers for Language Understanding.md -> PAPER
